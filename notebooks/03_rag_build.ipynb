# %% [markdown]
# # Building RAG Vector Store
# Build the Chroma vector store from processed job data for the AI Career Coach.

# %% [markdown]
# # 1. Load libraries

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

# %%
from src.data_loader import load_all_jobs
from src.rag_engine import build_vector_store
from src.utils import logger

# %% [markdown]
# ## 2. Load Job Data

# %%
df = load_all_jobs()
print(f"Loaded {len(df):,} job records")
df.head()
# Out:
# Loaded 555 job records
#    work_year experience_level employment_type                   job_title  \
# 0       2020        Mid Level              FT              Data Scientist
# 1       2020     Senior Level              FT  Machine Learning Scientist
# 2       2020     Senior Level              FT           Big Data Engineer
# 3       2020        Mid Level              FT        Product Data Analyst
# 4       2020     Senior Level              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833            Germany             0
# 1  260000             USD         260000              Japan             0
# 2   85000             GBP         109024     United Kingdom            50
# 3   20000             USD          20000           Honduras             0
# 4  150000             USD         150000      United States            50
#
#   company_location company_size
# 0          Germany            L
# 1            Japan            S
# 2   United Kingdom            M
# 3         Honduras            S
# 4    United States            L

# %% [markdown]
# ## 3. Build Chroma Vector Store
# This creates embeddings for text columns and stores them in `chroma_db/`.

# %%
vector_store = build_vector_store(
    df,
    text_columns=["job_title", "experience_level", "employment_type", "company_location", "company_size"],
    collection_name="job_market_v4",)
# Out:
# 2026-08-13 04:02:08,898 [INFO] job_market_v4: Building vector store from columns: ['job_title', 'experience_level', 'employment_type', 'company_location', 'company_size']
# 2026-08-13 04:02:08,920 [INFO] job_market_v4: Created 555 chunks from 555 documents
# /home/a/Documents/project/project-graduation/src/rag_engine.py:42: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   return HuggingFaceEmbeddings(model_name=EMBEDDING_MODEL)
# 2026-08-13 04:02:10,569 [INFO] sentence_transformers.base.model: No device provided, using cpu
# 2026-08-13 04:02:10,968 [INFO] sentence_transformers.base.model: Loading SentenceTransformer model from sentence-transformers/all-MiniLM-L6-v2.
# 2026-08-13 04:02:13,423 [INFO] chromadb.telemetry.product.posthog: Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2026-08-13 04:02:13,823 [ERROR] chromadb.telemetry.product.posthog: Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# 2026-08-13 04:02:13,864 [ERROR] chromadb.telemetry.product.posthog: Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# 2026-08-13 04:02:17,307 [INFO] job_market_v4: Vector store built — 555 documents

# %%
print(f"\n Vector store built successfully")
print(f"   Collection job_market_v4")
print(f"   Location chroma_db/")
# Out:
#  Vector store built successfully
#    Collection job_market_v4
#    Location chroma_db/
